# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/hemantwagh/Desktop/fessorpro/11_data_analysis/Unicorn_companies copy.csv')
df
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df1=df.head(30)
df1
# Out:
#            Company  Valuation Date Joined  \
# 0        Bytedance        180  07-04-2017
# 1           SpaceX        100  01-12-2012
# 2            SHEIN        100  03-07-2018
# 3           Stripe         95  23-01-2014
# 4           Klarna         46  12-12-2011
# 5            Canva         40  08-01-2018
# 6     Checkout.com         40  02-05-2019
# 7        Instacart         39  30-12-2014
# 8        JUUL Labs         38  20-12-2017
# 9       Databricks         38  05-02-2019
# 10         Revolut         33  26-04-2018
# 11      Epic Games         32  26-10-2018
# 12             FTX         32  20-07-2021
# 13        Fanatics         27  06-06-2012
# 14           Chime         25  05-03-2019
# 15          BYJU's         22  25-07-2017
# 16     J&T Express         20  07-04-2021
# 17     Xiaohongshu         20  31-03-2016
# 18            Miro         18  05-01-2022
# 19       Yuanfudao         17  31-05-2017
# 20           Rapyd         15  03-12-2019
# ...

# %%
df1
# Out:
#            Company  Valuation Date Joined  \
# 0        Bytedance        180  07-04-2017
# 1           SpaceX        100  01-12-2012
# 2            SHEIN        100  03-07-2018
# 3           Stripe         95  23-01-2014
# 4           Klarna         46  12-12-2011
# 5            Canva         40  08-01-2018
# 6     Checkout.com         40  02-05-2019
# 7        Instacart         39  30-12-2014
# 8        JUUL Labs         38  20-12-2017
# 9       Databricks         38  05-02-2019
# 10         Revolut         33  26-04-2018
# 11      Epic Games         32  26-10-2018
# 12             FTX         32  20-07-2021
# 13        Fanatics         27  06-06-2012
# 14           Chime         25  05-03-2019
# 15          BYJU's         22  25-07-2017
# 16     J&T Express         20  07-04-2021
# 17     Xiaohongshu         20  31-03-2016
# 18            Miro         18  05-01-2022
# 19       Yuanfudao         17  31-05-2017
# 20           Rapyd         15  03-12-2019
# ...

# %%
# df=df.set_index('Symbol')
df1.set_index('Industry',inplace=True)
df1
# Out:
#                                             Company  Valuation Date Joined  \
# Industry
# Artificial intelligence                   Bytedance        180  07-04-2017
# Other                                        SpaceX        100  01-12-2012
# E-commerce & direct-to-consumer               SHEIN        100  03-07-2018
# Fintech                                      Stripe         95  23-01-2014
# Fintech                                      Klarna         46  12-12-2011
# Internet software & services                  Canva         40  08-01-2018
# Fintech                                Checkout.com         40  02-05-2019
# Supply chain, logistics, & delivery       Instacart         39  30-12-2014
# Consumer & retail                         JUUL Labs         38  20-12-2017
# Data management & analytics              Databricks         38  05-02-2019
# Fintech                                     Revolut         33  26-04-2018
# ...

# %%
df3=df1.reset_index()

# %%
df3
# Out:
#                                Industry         Company  Valuation  \
# 0               Artificial intelligence       Bytedance        180
# 1                                 Other          SpaceX        100
# 2       E-commerce & direct-to-consumer           SHEIN        100
# 3                               Fintech          Stripe         95
# 4                               Fintech          Klarna         46
# 5          Internet software & services           Canva         40
# 6                               Fintech    Checkout.com         40
# 7   Supply chain, logistics, & delivery       Instacart         39
# 8                     Consumer & retail       JUUL Labs         38
# 9           Data management & analytics      Databricks         38
# 10                              Fintech         Revolut         33
# 11                                Other      Epic Games         32
# 12                              Fintech             FTX         32
# ...

# %%
df1.loc['Consumer & retail','Date Joined']
# Out:
# Industry
# Consumer & retail    20-12-2017
# Consumer & retail    01-03-2020
# Name: Date Joined, dtype: object

# %%
df3.loc["Supply chain, logistics, & delivery":"Artificial intelligence","City":"Year Founded"]
# Out:
# Empty DataFrame
# Columns: [City, Country, Continent, Year Founded]
# Index: []

# %%
df1.iloc[2,3]
# Out:
# 'Shenzhen'

# %%
df1.iloc[2:5,0:4]
# Out:
#                                 Company  Valuation Date Joined           City
# Industry
# E-commerce & direct-to-consumer   SHEIN        100  03-07-2018       Shenzhen
# Fintech                          Stripe         95  23-01-2014  San Francisco
# Fintech                          Klarna         46  12-12-2011      Stockholm

# %%
df1.iloc[-4:,2:4]
# Out:
#                                 Date Joined           City
# Industry
# Health                           16-10-2018        Waltham
# E-commerce & direct-to-consumer  20-07-2021       New York
# Internet software & services     10-10-2019  San Francisco
# Artificial intelligence          12-07-2019     Pittsburgh
