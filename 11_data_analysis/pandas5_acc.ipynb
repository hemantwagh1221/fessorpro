# %%
import pandas as pd 
df1=pd.read_csv('/Users/hemantwagh/Desktop/fessorpro/11_data_analysis/Unicorn_companies copy.csv')
df1
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   object
#  1   Valuation     1074 non-null   int64
#  2   Date Joined   1074 non-null   object
#  3   Industry      1074 non-null   object
#  4   City          1058 non-null   object
#  5   Country       1074 non-null   object
#  6   Continent     1074 non-null   object
#  7   Year Founded  1074 non-null   int64
#  8   Funding       1073 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 75.6+ KB

# %%
'hello'.upper()
# Out:
# 'HELLO'

# %%
df1['Company'].str.upper()
# Out:
# 0         BYTEDANCE
# 1            SPACEX
# 2             SHEIN
# 3            STRIPE
# 4            KLARNA
#            ...
# 1069       ZHAOGANG
# 1070    ZHUAN ZHUAN
# 1071       ZIHAIGUO
# 1072           ZOPA
# 1073          ZWIFT
# Name: Company, Length: 1074, dtype: object

# %%
df1['Date Joined'].str.replace('-','/')
# Out:
# 0       07/04/2017
# 1       01/12/2012
# 2       03/07/2018
# 3       23/01/2014
# 4       12/12/2011
#            ...
# 1069    29/06/2017
# 1070    18/04/2017
# 1071    06/05/2021
# 1072    19/10/2021
# 1073    16/09/2020
# Name: Date Joined, Length: 1074, dtype: object

# %%
df1['Year Founded'].astype('object')
df1
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   object
#  1   Valuation     1074 non-null   int64
#  2   Date Joined   1074 non-null   object
#  3   Industry      1074 non-null   object
#  4   City          1058 non-null   object
#  5   Country       1074 non-null   object
#  6   Continent     1074 non-null   object
#  7   Year Founded  1074 non-null   int64
#  8   Funding       1073 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 75.6+ KB

# %%
df1
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df1=df1.fillna(0)
df1
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df1['Funding'].max()
# Out:
# np.float64(999.0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   object
#  1   Valuation     1074 non-null   int64
#  2   Date Joined   1074 non-null   object
#  3   Industry      1074 non-null   object
#  4   City          1074 non-null   object
#  5   Country       1074 non-null   object
#  6   Continent     1074 non-null   object
#  7   Year Founded  1074 non-null   int64
#  8   Funding       1074 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 75.6+ KB

# %%
list2=[]
for i in df1['Date Joined']:
    if i[-3]=='[':
        list2.append(i[:-3])
    else:
        list2.append(i)
df1['Date Joined']=list2
df1
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   object
#  1   Valuation     1074 non-null   int64
#  2   Date Joined   1074 non-null   object
#  3   Industry      1074 non-null   object
#  4   City          1074 non-null   object
#  5   Country       1074 non-null   object
#  6   Continent     1074 non-null   object
#  7   Year Founded  1074 non-null   int64
#  8   Funding       1074 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 75.6+ KB

# %%
df1
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   object
#  1   Valuation     1074 non-null   int64
#  2   Date Joined   1074 non-null   object
#  3   Industry      1074 non-null   object
#  4   City          1074 non-null   object
#  5   Country       1074 non-null   object
#  6   Continent     1074 non-null   object
#  7   Year Founded  1074 non-null   object
#  8   Funding       1074 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 75.6+ KB

# %%
list1=[]
for i in data1['Index weighting']:
    list1.append(float(i.replace('%','')))
data1['Index weighting']=list1

# %%
list2=[]
for i in data2['Date added[16]']:
    if i[-3]=='[':
        list2.append(i[:-3])
    else:
        list2.append(i)
data2['Date added[16]']=list2
data2

# %%
df=data
print("mean: ")
print(df["Valuation"].mean())

print("median: ")
print(df["Valuation"].median())

print("mode: ")
print(df["Valuation"].mode()[0])

print("minimum: ")
print(df["Valuation"].min())

print("maximum: ")
print(df["Valuation"].max())

print("variance: ")
print(df["Valuation"].var())

print("standard deviation: ")
print(df["Valuation"].std())

# %%
data.set_index('Company',inplace=True)
data

# %%
data.drop('Zopa',axis=0)
